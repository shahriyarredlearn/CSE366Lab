# %% [markdown]
# <a href="https://colab.research.google.com/github/shahriyarredlearn/CSE366Lab/blob/CSE366Lab02/CSE366LAB3_Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing all the necessery libraries
import random
import math
import matplotlib.pyplot as plt

# %%
#utilities

def argmaxall(gen):
    """gen is a generator of (element,value) pairs, where value is a real.
    argmaxall returns a list of all of the elements with maximal value.
    """
    maxv = -math.inf       # negative infinity
    maxvals = []      # list of maximal elements
    for (e,v) in gen:
        if v>maxv:
            maxvals,maxv = [e], v
        elif v==maxv:
            maxvals.append(e)
    return maxvals

# %%
def argmaxe(gen):
    """gen is a generator of (element,value) pairs, where value is a real.
    argmaxe returns an element with maximal value.
    If there are multiple elements with the max value, one is returned at random.
    """
    return random.choice(argmaxall(gen))

# %%
def argmax(lst):
    """returns maximum index in a list"""
    return argmaxe(enumerate(lst))

# %%
def argmaxd(dct):
   """returns the arg max of a dictionary dct"""
   return argmaxe(dct.items())

# %%
def flip(prob):
    """return true with probability prob"""
    return random.random() < prob

# %%
def select_from_dist(item_prob_dist):
  #{6:0.1, 5:0.1, 4:0.1, 3:0.3, 2:0.2, 1:0.2}
    """ returns a value from a distribution.
    item_prob_dist is an item:probability dictionary, where the
        probabilities sum to 1.
    returns an item chosen in proportion to its probability
    """
    ranreal = random.random()
    for (it,prob) in item_prob_dist.items():
        if ranreal < prob:
            return it
        else:
            ranreal -= prob
    raise RuntimeError(f"{item_prob_dist} is not a probability distribution")

# %%
class Displayable(object):
    """Class that uses 'display'.
    The amount of detail is controlled by max_display_level
    """
    max_display_level = 1   # can be overridden in subclasses or instances

    def display(self,level,*args,**nargs):
        """print the arguments if level is less than or equal to the
        current max_display_level.
        level is an integer.
        the other arguments are whatever arguments print can take.
        """

        if level <= self.max_display_level:
            print(*args, **nargs)  ##if error you are using Python2 not Python3

# %%
class Plot_history(object):
    """Set up the plot for history of price and number in stock"""
    def __init__(self, ag, env):
        self.ag = ag
        self.env = env
        plt.ion()
        plt.xlabel("Time")
        plt.ylabel("Value")


    def plot_env_hist(self):
        """plot history of price and instock"""
        num = len(env.stock_history)
        plt.plot(range(num),env.price_history,label="Price")
        plt.plot(range(num),env.stock_history,label="In stock")
        plt.legend()
        #plt.draw()

    def plot_agent_hist(self):
        """plot history of buying"""
        num = len(ag.buy_history)
        plt.bar(range(1,num+1), ag.buy_history, label="Bought")
        plt.legend()
        #plt.draw()

# %% [markdown]
# **Agent Controller**

# %%
#from display import Displayable

class Agent(Displayable):

    def initial_action(self, percept):
        """return the initial action."""
        return self.select_action(percept)   # same as select_action

    def select_action(self, percept):
        """return the next action (and update internal state) given percept
        percept is variable:value dictionary
        """
        raise NotImplementedError("go")   # abstract method

# %% [markdown]
# Agent Virtual Environment

# %%
class Environment(Displayable):
    def initial_percept(self):
        """returns the initial percept for the agent"""
        raise NotImplementedError("initial_percept")   # abstract method

    def do(self, action):
        """does the action in the environment
        returns the next percept """
        raise NotImplementedError("Environment.do")   # abstract method

# %% [markdown]
# Simulation of the realworld task

# %%
class Simulate(Displayable):
    """simulate the interaction between the agent and the environment
    for n time steps.
    Returns a pair of the agent state and the environment state.
    """
    def __init__(self,agent, environment):
        self.agent = agent
        self.env = environment
        self.percept = self.env.initial_percept()
        self.percept_history = [self.percept]
        self.action_history = []

    def go(self, n):
        for i in range(n):
            action = self.agent.select_action(self.percept)
            print(f"i={i} action={action}")

            self.percept = self.env.do(action,i)
            print(f"      percept={self.percept}")

# %%
class TP_env(Environment):
    #new prices
    price_delta = [-10, 5, 0, 30, -15, 25, -5, -40, 10, 0, 20, -10, 5, -15, -30,
                    20, 50, -20, -35, 15, -5, 0, 25, 5, 10, 0, 10, -5, 0, 0, 0,
                    10, -5, -20, 15, 5, 10, -100, 100, 10, 0, -10, 0, 0, 10, -5,
                    10, 15, -10, -50, 30, 40, 5, 0, 10, 0, 5, 0, 10, 0, -60, 50,
                    10, 5, 10, -5, 0, 0, 5, -5, -70, 60]

    sd = 8  # new noise standard deviation

    def __init__(self): # removed extra indent here
        """Updated paper buying agent"""
        self.time=0
        self.stock=20
        self.stock_history = []  # memory of the stock history
        self.price_history = []  # memory of the price history

    def initial_percept(self):
        """return initial percept"""
        self.stock_history.append(self.stock)
        self.price = round(234+self.sd*random.gauss(0,1))
        self.price_history.append(self.price)
        #print(f"Initial price: {self.price} ,instock: {self.stock}")
        return {'price': self.price,
                'instock': self.stock}

    def do(self, action, time_unit):
        """does action (buy) and returns percept consisting of price and instock"""
        used = select_from_dist({6:0.1, 5:0.1, 4:0.1, 3:0.3, 2:0.2, 1:0.2})
        print(f"i={time_unit} used={used}")
        # used = select_from_dist({7:0.1, 6:0.2, 5:0.2, 4:0.3, 3:0.1, 2:0.1}) # uses more paper
        bought = action['buy']
        self.stock = self.stock+bought-used
        self.stock_history.append(self.stock)
        self.time += 1
        self.price =  round(self.price
                        + self.price_delta[self.time%len(self.price_delta)] # repeating pattern
                        + self.sd*random.gauss(0,1)) # plus randomness
        self.price_history.append(self.price)
        return {'price': self.price,
                'instock': self.stock}

# %%
class TP_agent(Agent):
    def __init__(self):
        self.spent = 0
        percept = env.initial_percept()
        self.ave = self.last_price = percept['price']
        self.instock = percept['instock']
        self.buy_history = []

    def select_action(self, percept):
        """return next action to carry out
        """
        self.last_price = percept['price']
        self.ave = self.ave+(self.last_price-self.ave)*0.08
        self.instock = percept['instock']
        if self.last_price < 0.7*self.ave and self.instock < 30:
            tobuy = 15
        elif self.instock < 10:
            tobuy = 5
        else:
            tobuy = 0
        self.spent += tobuy*self.last_price
        self.buy_history.append(tobuy)
        #print(f"agent buy:{tobuy}")
        return {'buy': tobuy}

# %%
env = TP_env()
ag = TP_agent()
sim = Simulate(ag,env)
sim.go(10)
ag.spent/env.time
# Out:
# i=0 action={'buy': 0}
# i=0 used=1
#       percept={'price': 245, 'instock': 19}
# i=1 action={'buy': 0}
# i=1 used=6
#       percept={'price': 237, 'instock': 13}
# i=2 action={'buy': 0}
# i=2 used=3
#       percept={'price': 264, 'instock': 10}
# i=3 action={'buy': 0}
# i=3 used=5
#       percept={'price': 249, 'instock': 5}
# i=4 action={'buy': 5}
# i=4 used=1
#       percept={'price': 284, 'instock': 9}
# i=5 action={'buy': 5}
# i=5 used=4
#       percept={'price': 283, 'instock': 10}
# i=6 action={'buy': 0}
# i=6 used=2
#       percept={'price': 232, 'instock': 8}
# i=7 action={'buy': 5}
# i=7 used=1
#       percept={'price': 234, 'instock': 12}
# i=8 action={'buy': 0}
# i=8 used=3
#       percept={'price': 235, 'instock': 9}
# i=9 action={'buy': 5}
# i=9 used=1
#       percept={'price': 248, 'instock': 13}
# 500.0

# %%
sim.go(100);
# Out:
# i=0 action={'buy': 0}
# i=0 used=1
#       percept={'price': 238, 'instock': 12}
# i=1 action={'buy': 0}
# i=1 used=3
#       percept={'price': 232, 'instock': 9}
# i=2 action={'buy': 5}
# i=2 used=5
#       percept={'price': 214, 'instock': 9}
# i=3 action={'buy': 5}
# i=3 used=6
#       percept={'price': 174, 'instock': 8}
# i=4 action={'buy': 5}
# i=4 used=2
#       percept={'price': 183, 'instock': 11}
# i=5 action={'buy': 0}
# i=5 used=1
#       percept={'price': 238, 'instock': 10}
# i=6 action={'buy': 0}
# i=6 used=3
#       percept={'price': 205, 'instock': 7}
# i=7 action={'buy': 5}
# i=7 used=3
#       percept={'price': 187, 'instock': 9}
# i=8 action={'buy': 5}
# i=8 used=2
#       percept={'price': 213, 'instock': 12}
# i=9 action={'buy': 0}
# i=9 used=3
#       percept={'price': 215, 'instock': 9}
# i=10 action={'buy': 5}
# i=10 used=2
#       percept={'price': 219, 'instock': 12}
# i=11 action={'buy': 0}
# i=11 used=3
#       percept={'price': 236, 'instock': 9}
# i=12 action={'buy': 5}
# i=12 used=2
#       percept={'price': 245, 'instock': 12}
# i=13 action={'buy': 0}
# i=13 used=6
#       percept={'price': 256, 'instock': 6}
# i=14 action={'buy': 5}
# i=14 used=3
#       percept={'price': 248, 'instock': 8}
# i=15 action={'buy': 5}
# i=15 used=3
#       percept={'price': 241, 'instock': 10}
# i=16 action={'buy': 0}
# i=16 used=4
#       percept={'price': 235, 'instock': 6}
# i=17 action={'buy': 5}
# i=17 used=1
#       percept={'price': 229, 'instock': 10}
# i=18 action={'buy': 0}
# i=18 used=4
#       percept={'price': 233, 'instock': 6}
# i=19 action={'buy': 5}
# i=19 used=1
#       percept={'price': 227, 'instock': 10}
# i=20 action={'buy': 0}
# i=20 used=2
#       percept={'price': 226, 'instock': 8}
# i=21 action={'buy': 5}
# i=21 used=2
#       percept={'price': 224, 'instock': 11}
# i=22 action={'buy': 0}
# i=22 used=3
#       percept={'price': 204, 'instock': 8}
# i=23 action={'buy': 5}
# i=23 used=2
#       percept={'price': 210, 'instock': 11}
# i=24 action={'buy': 0}
# i=24 used=3
#       percept={'price': 211, 'instock': 8}
# i=25 action={'buy': 5}
# i=25 used=6
#       percept={'price': 208, 'instock': 7}
# i=26 action={'buy': 5}
# i=26 used=6
#       percept={'price': 104, 'instock': 6}
# i=27 action={'buy': 15}
# i=27 used=3
#       percept={'price': 208, 'instock': 18}
# i=28 action={'buy': 0}
# i=28 used=2
#       percept={'price': 211, 'instock': 16}
# i=29 action={'buy': 0}
# i=29 used=1
#       percept={'price': 212, 'instock': 15}
# i=30 action={'buy': 0}
# i=30 used=2
#       percept={'price': 192, 'instock': 13}
# i=31 action={'buy': 0}
# i=31 used=4
#       percept={'price': 192, 'instock': 9}
# i=32 action={'buy': 5}
# i=32 used=3
#       percept={'price': 188, 'instock': 11}
# i=33 action={'buy': 0}
# i=33 used=4
#       percept={'price': 210, 'instock': 7}
# i=34 action={'buy': 5}
# i=34 used=2
#       percept={'price': 195, 'instock': 10}
# i=35 action={'buy': 0}
# i=35 used=3
#       percept={'price': 214, 'instock': 7}
# i=36 action={'buy': 5}
# i=36 used=1
#       percept={'price': 228, 'instock': 11}
# i=37 action={'buy': 0}
# i=37 used=1
#       percept={'price': 215, 'instock': 10}
# i=38 action={'buy': 0}
# i=38 used=2
#       percept={'price': 169, 'instock': 8}
# i=39 action={'buy': 5}
# i=39 used=5
#       percept={'price': 187, 'instock': 8}
# i=40 action={'buy': 5}
# i=40 used=3
#       percept={'price': 234, 'instock': 10}
# i=41 action={'buy': 0}
# i=41 used=2
#       percept={'price': 255, 'instock': 8}
# i=42 action={'buy': 5}
# i=42 used=5
#       percept={'price': 246, 'instock': 8}
# i=43 action={'buy': 5}
# i=43 used=2
#       percept={'price': 260, 'instock': 11}
# i=44 action={'buy': 0}
# i=44 used=4
#       percept={'price': 267, 'instock': 7}
# i=45 action={'buy': 5}
# i=45 used=3
#       percept={'price': 263, 'instock': 9}
# i=46 action={'buy': 5}
# i=46 used=3
#       percept={'price': 263, 'instock': 11}
# i=47 action={'buy': 0}
# i=47 used=1
#       percept={'price': 261, 'instock': 10}
# i=48 action={'buy': 0}
# i=48 used=3
#       percept={'price': 267, 'instock': 7}
# i=49 action={'buy': 5}
# i=49 used=1
#       percept={'price': 207, 'instock': 11}
# i=50 action={'buy': 0}
# i=50 used=4
#       percept={'price': 269, 'instock': 7}
# i=51 action={'buy': 5}
# i=51 used=6
#       percept={'price': 284, 'instock': 6}
# i=52 action={'buy': 5}
# i=52 used=1
#       percept={'price': 279, 'instock': 10}
# i=53 action={'buy': 0}
# i=53 used=1
#       percept={'price': 290, 'instock': 9}
# i=54 action={'buy': 5}
# i=54 used=3
#       percept={'price': 292, 'instock': 11}
# i=55 action={'buy': 0}
# i=55 used=5
#       percept={'price': 278, 'instock': 6}
# i=56 action={'buy': 5}
# i=56 used=6
#       percept={'price': 284, 'instock': 5}
# i=57 action={'buy': 5}
# i=57 used=5
#       percept={'price': 287, 'instock': 5}
# i=58 action={'buy': 5}
# i=58 used=4
#       percept={'price': 277, 'instock': 6}
# i=59 action={'buy': 5}
# i=59 used=6
#       percept={'price': 210, 'instock': 5}
# i=60 action={'buy': 5}
# i=60 used=2
#       percept={'price': 284, 'instock': 8}
# i=61 action={'buy': 5}
# i=61 used=1
#       percept={'price': 278, 'instock': 12}
# i=62 action={'buy': 0}
# i=62 used=4
#       percept={'price': 277, 'instock': 8}
# i=63 action={'buy': 5}
# i=63 used=6
#       percept={'price': 270, 'instock': 7}
# i=64 action={'buy': 5}
# i=64 used=2
#       percept={'price': 303, 'instock': 10}
# i=65 action={'buy': 0}
# i=65 used=3
#       percept={'price': 283, 'instock': 7}
# i=66 action={'buy': 5}
# i=66 used=4
#       percept={'price': 310, 'instock': 8}
# i=67 action={'buy': 5}
# i=67 used=5
#       percept={'price': 299, 'instock': 8}
# i=68 action={'buy': 5}
# i=68 used=3
#       percept={'price': 249, 'instock': 10}
# i=69 action={'buy': 0}
# i=69 used=1
#       percept={'price': 251, 'instock': 9}
# i=70 action={'buy': 5}
# i=70 used=2
#       percept={'price': 267, 'instock': 12}
# i=71 action={'buy': 0}
# i=71 used=3
#       percept={'price': 277, 'instock': 9}
# i=72 action={'buy': 5}
# i=72 used=3
#       percept={'price': 264, 'instock': 11}
# i=73 action={'buy': 0}
# i=73 used=6
#       percept={'price': 273, 'instock': 5}
# i=74 action={'buy': 5}
# i=74 used=5
#       percept={'price': 265, 'instock': 5}
# i=75 action={'buy': 5}
# i=75 used=5
#       percept={'price': 245, 'instock': 5}
# i=76 action={'buy': 5}
# i=76 used=2
#       percept={'price': 253, 'instock': 8}
# i=77 action={'buy': 5}
# i=77 used=6
#       percept={'price': 303, 'instock': 7}
# i=78 action={'buy': 5}
# i=78 used=3
#       percept={'price': 278, 'instock': 9}
# i=79 action={'buy': 5}
# i=79 used=1
#       percept={'price': 243, 'instock': 13}
# i=80 action={'buy': 0}
# i=80 used=2
#       percept={'price': 268, 'instock': 11}
# i=81 action={'buy': 0}
# i=81 used=1
#       percept={'price': 281, 'instock': 10}
# i=82 action={'buy': 0}
# i=82 used=4
#       percept={'price': 284, 'instock': 6}
# i=83 action={'buy': 5}
# i=83 used=1
#       percept={'price': 308, 'instock': 10}
# i=84 action={'buy': 0}
# i=84 used=3
#       percept={'price': 309, 'instock': 7}
# i=85 action={'buy': 5}
# i=85 used=5
#       percept={'price': 307, 'instock': 7}
# i=86 action={'buy': 5}
# i=86 used=5
#       percept={'price': 315, 'instock': 7}
# i=87 action={'buy': 5}
# i=87 used=2
#       percept={'price': 327, 'instock': 10}
# i=88 action={'buy': 0}
# i=88 used=4
#       percept={'price': 325, 'instock': 6}
# i=89 action={'buy': 5}
# i=89 used=3
#       percept={'price': 333, 'instock': 8}
# i=90 action={'buy': 5}
# i=90 used=6
#       percept={'price': 353, 'instock': 7}
# i=91 action={'buy': 5}
# i=91 used=3
#       percept={'price': 349, 'instock': 9}
# i=92 action={'buy': 5}
# i=92 used=3
#       percept={'price': 353, 'instock': 11}
# i=93 action={'buy': 0}
# i=93 used=1
#       percept={'price': 357, 'instock': 10}
# i=94 action={'buy': 0}
# i=94 used=5
#       percept={'price': 343, 'instock': 5}
# i=95 action={'buy': 5}
# i=95 used=3
#       percept={'price': 356, 'instock': 7}
# i=96 action={'buy': 5}
# i=96 used=5
#       percept={'price': 359, 'instock': 7}
# i=97 action={'buy': 5}
# i=97 used=2
#       percept={'price': 366, 'instock': 10}
# i=98 action={'buy': 0}
# i=98 used=2
#       percept={'price': 272, 'instock': 8}
# i=99 action={'buy': 5}
# i=99 used=3
#       percept={'price': 388, 'instock': 10}

# %%
sim.go(100);
print(f"agent spent ${ag.spent/100}")
pl = Plot_history(ag,env); pl.plot_env_hist(); pl.plot_agent_hist()
# Out:
# i=0 action={'buy': 0}
# i=0 used=2
#       percept={'price': 400, 'instock': 8}
# i=1 action={'buy': 5}
# i=1 used=6
#       percept={'price': 407, 'instock': 7}
# i=2 action={'buy': 5}
# i=2 used=6
#       percept={'price': 390, 'instock': 6}
# i=3 action={'buy': 5}
# i=3 used=3
#       percept={'price': 401, 'instock': 8}
# i=4 action={'buy': 5}
# i=4 used=1
#       percept={'price': 407, 'instock': 12}
# i=5 action={'buy': 0}
# i=5 used=2
#       percept={'price': 411, 'instock': 10}
# i=6 action={'buy': 0}
# i=6 used=1
#       percept={'price': 408, 'instock': 9}
# i=7 action={'buy': 5}
# i=7 used=3
#       percept={'price': 420, 'instock': 11}
# i=8 action={'buy': 0}
# i=8 used=4
#       percept={'price': 436, 'instock': 7}
# i=9 action={'buy': 5}
# i=9 used=1
#       percept={'price': 430, 'instock': 11}
# i=10 action={'buy': 0}
# i=10 used=2
#       percept={'price': 374, 'instock': 9}
# i=11 action={'buy': 5}
# i=11 used=1
#       percept={'price': 400, 'instock': 13}
# i=12 action={'buy': 0}
# i=12 used=6
#       percept={'price': 436, 'instock': 7}
# i=13 action={'buy': 5}
# i=13 used=5
#       percept={'price': 438, 'instock': 7}
# i=14 action={'buy': 5}
# i=14 used=1
#       percept={'price': 423, 'instock': 11}
# i=15 action={'buy': 0}
# i=15 used=2
#       percept={'price': 427, 'instock': 9}
# i=16 action={'buy': 5}
# i=16 used=5
#       percept={'price': 431, 'instock': 9}
# i=17 action={'buy': 5}
# i=17 used=1
#       percept={'price': 435, 'instock': 13}
# i=18 action={'buy': 0}
# i=18 used=3
#       percept={'price': 439, 'instock': 10}
# i=19 action={'buy': 0}
# i=19 used=6
#       percept={'price': 454, 'instock': 4}
# i=20 action={'buy': 5}
# i=20 used=1
#       percept={'price': 452, 'instock': 8}
# i=21 action={'buy': 5}
# i=21 used=6
#       percept={'price': 386, 'instock': 7}
# i=22 action={'buy': 5}
# i=22 used=1
#       percept={'price': 425, 'instock': 11}
# i=23 action={'buy': 0}
# i=23 used=1
#       percept={'price': 432, 'instock': 10}
# i=24 action={'buy': 0}
# i=24 used=2
#       percept={'price': 443, 'instock': 8}
# i=25 action={'buy': 5}
# i=25 used=6
#       percept={'price': 460, 'instock': 7}
# i=26 action={'buy': 5}
# i=26 used=1
#       percept={'price': 474, 'instock': 11}
# i=27 action={'buy': 0}
# i=27 used=1
#       percept={'price': 478, 'instock': 10}
# i=28 action={'buy': 0}
# i=28 used=3
#       percept={'price': 483, 'instock': 7}
# i=29 action={'buy': 5}
# i=29 used=3
#       percept={'price': 485, 'instock': 9}
# i=30 action={'buy': 5}
# i=30 used=3
#       percept={'price': 482, 'instock': 11}
# i=31 action={'buy': 0}
# i=31 used=6
#       percept={'price': 416, 'instock': 5}
# i=32 action={'buy': 5}
# i=32 used=3
#       percept={'price': 478, 'instock': 7}
# i=33 action={'buy': 5}
# i=33 used=2
#       percept={'price': 469, 'instock': 10}
# i=34 action={'buy': 0}
# i=34 used=1
#       percept={'price': 474, 'instock': 9}
# i=35 action={'buy': 5}
# i=35 used=1
#       percept={'price': 464, 'instock': 13}
# i=36 action={'buy': 0}
# i=36 used=2
#       percept={'price': 493, 'instock': 11}
# i=37 action={'buy': 0}
# i=37 used=1
#       percept={'price': 477, 'instock': 10}
# i=38 action={'buy': 0}
# i=38 used=6
#       percept={'price': 497, 'instock': 4}
# i=39 action={'buy': 5}
# i=39 used=2
#       percept={'price': 484, 'instock': 7}
# i=40 action={'buy': 5}
# i=40 used=6
#       percept={'price': 433, 'instock': 6}
# i=41 action={'buy': 5}
# i=41 used=2
#       percept={'price': 452, 'instock': 9}
# i=42 action={'buy': 5}
# i=42 used=3
#       percept={'price': 462, 'instock': 11}
# i=43 action={'buy': 0}
# i=43 used=1
#       percept={'price': 478, 'instock': 10}
# i=44 action={'buy': 0}
# i=44 used=3
#       percept={'price': 463, 'instock': 7}
# i=45 action={'buy': 5}
# i=45 used=6
#       percept={'price': 462, 'instock': 6}
# i=46 action={'buy': 5}
# i=46 used=5
#       percept={'price': 451, 'instock': 6}
# i=47 action={'buy': 5}
# i=47 used=4
#       percept={'price': 411, 'instock': 7}
# i=48 action={'buy': 5}
# i=48 used=2
#       percept={'price': 434, 'instock': 10}
# i=49 action={'buy': 0}
# i=49 used=2
#       percept={'price': 481, 'instock': 8}
# i=50 action={'buy': 5}
# i=50 used=3
#       percept={'price': 459, 'instock': 10}
# i=51 action={'buy': 0}
# i=51 used=1
#       percept={'price': 410, 'instock': 9}
# i=52 action={'buy': 5}
# i=52 used=4
#       percept={'price': 421, 'instock': 10}
# i=53 action={'buy': 0}
# i=53 used=3
#       percept={'price': 407, 'instock': 7}
# i=54 action={'buy': 5}
# i=54 used=3
#       percept={'price': 413, 'instock': 9}
# i=55 action={'buy': 5}
# i=55 used=3
#       percept={'price': 432, 'instock': 11}
# i=56 action={'buy': 0}
# i=56 used=2
#       percept={'price': 435, 'instock': 9}
# i=57 action={'buy': 5}
# i=57 used=2
#       percept={'price': 440, 'instock': 12}
# i=58 action={'buy': 0}
# i=58 used=3
#       percept={'price': 441, 'instock': 9}
# i=59 action={'buy': 5}
# i=59 used=5
#       percept={'price': 445, 'instock': 9}
# i=60 action={'buy': 5}
# i=60 used=3
#       percept={'price': 444, 'instock': 11}
# i=61 action={'buy': 0}
# i=61 used=4
#       percept={'price': 445, 'instock': 7}
# i=62 action={'buy': 5}
# i=62 used=1
#       percept={'price': 454, 'instock': 11}
# i=63 action={'buy': 0}
# i=63 used=2
#       percept={'price': 449, 'instock': 9}
# i=64 action={'buy': 5}
# i=64 used=4
#       percept={'price': 460, 'instock': 10}
# i=65 action={'buy': 0}
# i=65 used=2
#       percept={'price': 454, 'instock': 8}
# i=66 action={'buy': 5}
# i=66 used=3
#       percept={'price': 445, 'instock': 10}
# i=67 action={'buy': 0}
# i=67 used=5
#       percept={'price': 459, 'instock': 5}
# i=68 action={'buy': 5}
# i=68 used=3
#       percept={'price': 477, 'instock': 7}
# i=69 action={'buy': 5}
# i=69 used=1
#       percept={'price': 480, 'instock': 11}
# i=70 action={'buy': 0}
# i=70 used=6
#       percept={'price': 376, 'instock': 5}
# i=71 action={'buy': 5}
# i=71 used=6
#       percept={'price': 480, 'instock': 4}
# i=72 action={'buy': 5}
# i=72 used=2
#       percept={'price': 468, 'instock': 7}
# i=73 action={'buy': 5}
# i=73 used=2
#       percept={'price': 458, 'instock': 10}
# i=74 action={'buy': 0}
# i=74 used=2
#       percept={'price': 442, 'instock': 8}
# i=75 action={'buy': 5}
# i=75 used=2
#       percept={'price': 441, 'instock': 11}
# i=76 action={'buy': 0}
# i=76 used=3
#       percept={'price': 447, 'instock': 8}
# i=77 action={'buy': 5}
# i=77 used=1
#       percept={'price': 471, 'instock': 12}
# i=78 action={'buy': 0}
# i=78 used=2
#       percept={'price': 474, 'instock': 10}
# i=79 action={'buy': 0}
# i=79 used=6
#       percept={'price': 486, 'instock': 4}
# i=80 action={'buy': 5}
# i=80 used=3
#       percept={'price': 490, 'instock': 6}
# i=81 action={'buy': 5}
# i=81 used=1
#       percept={'price': 484, 'instock': 10}
# i=82 action={'buy': 0}
# i=82 used=3
#       percept={'price': 442, 'instock': 7}
# i=83 action={'buy': 5}
# i=83 used=1
#       percept={'price': 478, 'instock': 11}
# i=84 action={'buy': 0}
# i=84 used=1
#       percept={'price': 521, 'instock': 10}
# i=85 action={'buy': 0}
# i=85 used=3
#       percept={'price': 516, 'instock': 7}
# i=86 action={'buy': 5}
# i=86 used=1
#       percept={'price': 515, 'instock': 11}
# i=87 action={'buy': 0}
# i=87 used=1
#       percept={'price': 525, 'instock': 10}
# i=88 action={'buy': 0}
# i=88 used=1
#       percept={'price': 515, 'instock': 9}
# i=89 action={'buy': 5}
# i=89 used=4
#       percept={'price': 523, 'instock': 10}
# i=90 action={'buy': 0}
# i=90 used=4
#       percept={'price': 516, 'instock': 6}
# i=91 action={'buy': 5}
# i=91 used=1
#       percept={'price': 527, 'instock': 10}
# i=92 action={'buy': 0}
# i=92 used=1
#       percept={'price': 543, 'instock': 9}
# i=93 action={'buy': 5}
# i=93 used=1
#       percept={'price': 465, 'instock': 13}
# i=94 action={'buy': 0}
# i=94 used=1
#       percept={'price': 520, 'instock': 12}
# i=95 action={'buy': 0}
# i=95 used=4
#       percept={'price': 526, 'instock': 8}
# i=96 action={'buy': 5}
# i=96 used=2
#       percept={'price': 518, 'instock': 11}
# i=97 action={'buy': 0}
# i=97 used=1
#       percept={'price': 534, 'instock': 10}
# i=98 action={'buy': 0}
# i=98 used=2
#       percept={'price': 531, 'instock': 8}
# i=99 action={'buy': 5}
# i=99 used=3
#       percept={'price': 541, 'instock': 10}
# agent spent $2082.2
